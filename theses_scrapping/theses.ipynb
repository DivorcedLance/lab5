# %%
import pandas as pd

# %%
theses_details_path = './theses_details.csv'
theses_details_df = pd.read_csv(theses_details_path, encoding='utf-8', delimiter=',')
theses_details_df
# Out:
#                                                   Link  \
# 0    https://cybertesis.unmsm.edu.pe/item/9330303e-...
# 1    https://cybertesis.unmsm.edu.pe/item/ac7bb6fb-...
# 2    https://cybertesis.unmsm.edu.pe/item/b0182161-...
# 3    https://cybertesis.unmsm.edu.pe/item/158bc503-...
# 4    https://cybertesis.unmsm.edu.pe/item/f5132d6b-...
# ..                                                 ...
# 911  https://cybertesis.unmsm.edu.pe/item/983bb7b2-...
# 912  https://cybertesis.unmsm.edu.pe/item/f356b833-...
# 913  https://cybertesis.unmsm.edu.pe/item/932b0de3-...
# 914  https://cybertesis.unmsm.edu.pe/item/71469fd2-...
# 915  https://cybertesis.unmsm.edu.pe/item/d061d1ed-...
#
#                                                 Título  \
# 0    Adaptación de la guía PMBOK para documentar, e...
# 1    Adaptación del algoritmo Grasp en el diseño ef...
# 2    Adecuación de la gestión de documentos para la...
# 3    Adecuación del sistema BSCS usando el framewor...
# ...

# %%
theses_details_df.to_csv('theses_details_semicolon.csv', sep=';', index=False)
